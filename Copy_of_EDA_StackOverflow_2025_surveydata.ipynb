# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-lvrk/Data-Analysis-project/blob/main/Copy_of_EDA_StackOverflow_2025_surveydata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 EDA Case Study: Stack Overflow Annual Developer Survey 2020
#
# ## 👨‍💻 Author
# **L Hareesh**
#
#
# ---
#
# ## 📌 Project Overview
#
# This project performs **Exploratory Data Analysis (EDA)** on the **Stack Overflow Annual Developer Survey 2025 dataset**.
# The dataset contains responses from **65,000+ developers worldwide**, where they shared details about their age, countries, education, jobs, salaries, programming languages, and preferences.
#
# The main goal is to analyze and visualize the data to understand **global developer trends in 2020**.
#
# ---
#
# ## 📝 Understanding the Title
#
# ### 🔹 What is Stack Overflow?
# A popular website where programmers ask and answer coding questions.
#
# ### 🔹 What is the Annual Developer Survey?
# Every year, Stack Overflow collects responses from developers worldwide about their demographics, skills, and work.
#
# ### 🔹 What are Responses?
# Each respondent (developer) provides answers. Example:
#
# * Question: *What programming languages do you use?*
# * Response: *Python, JavaScript, SQL*
#
# ### 🔹 What does Analyzing Responses mean?
# Studying those answers to find insights like:
#
# * Most popular programming languages
# * Average salaries by country
# * Work preferences during COVID-19 (2020)
#
# ### 🔹 Where does the Data come from?
# Published by **Stack Overflow**, freely available on their research page or Kaggle.
#
# ---
#
# ## 💡 What You Can Do with the Data
#
# 1. **Demographics** – Age, gender, countries of developers.
# 2. **Programming Languages & Tools** – Most popular languages, databases, frameworks.
# 3. **Job & Salary Analysis** – Salary by country, experience, education.
# 4. **Learning & Education** – University vs self-taught vs bootcamp.
# 5. **Work Preferences** – Remote work, job satisfaction, working hours.
# 6. **Trends & Patterns** – Younger vs older developers, technology shifts.
# 7. **Advanced Analysis** – Correlations, clustering, deeper insights.
#
# ---
#
# ## 🚀 Roadmap for EDA
#
# ### **Step 1: Load the Data**
# * Import libraries (`pandas`, `matplotlib`, `seaborn`)
# * Load dataset with `pd.read_csv()`
# * Check shape (rows, columns) and first few rows
#
# ---
#
# ### **Step 2: Understand the Data**
# * `df.info()` → Column names & datatypes
# * `df.describe()` → Summary stats
# * `df.isnull().sum()` → Missing values
#
# ---
#
# ### **Step 3: Clean the Data**
# * Remove irrelevant columns (IDs, metadata)
# * Handle missing values (drop/fill)
# * Rename columns (e.g., `YearsCodePro → Years_Professional`)
# * Convert text into numeric values where needed
#
# ---
#
# ### **Step 4: Demographics**
# * Age distribution (histogram)
# * Top countries by respondents
# * Gender distribution
#
# ---
#
# ### **Step 5: Programming Languages & Tools**
# * Most popular programming languages (bar chart)
# * Databases, frameworks, cloud platforms analysis
#
# ---
#
# ### **Step 6: Job & Salary**
# * Salary distribution (boxplot)
# * Salary by country
# * Salary vs years of experience
# * Salary vs education level
#
# ---
#
# ### **Step 7: Learning & Education**
# * Coding learning methods (bootcamp, university, self-taught)
# * Education level vs salary
# * Education level vs languages used
#
# ---
#
# ### **Step 8: Work Preferences**
# * Remote work preference (important in 2020 – pandemic)
# * Job satisfaction levels
# * Weekly working hours
#
# ---
#
# ### **Step 9: Correlation & Multivariate Analysis**
# * Correlation heatmap (experience, age, salary)
# * Salary vs Experience scatterplot
# * Grouping developers by skills (optional clustering)
#
# ---
#
# ### **Step 10: Summarize Insights**
# * Top 3 languages: **JavaScript, Python, SQL**
# * **US developers** earn highest salaries; **India** has more developers but lower median salary
# * Younger developers → Python; Older developers → Java, C#
# * Rise of self-taught developers
#
# ---
#
# ## 🔑 Final Summary
#
# This project analyzes the **Stack Overflow 2020 Developer Survey** to uncover:
#
# * Who the developers are
# * What tools they use
# * How much they earn
# * How they learn coding
# * How their preferences changed in 2020 (COVID-19 year)
#
# It helps us **understand global trends in software development**.
#
# ---
#
# ## 🙌 Acknowledgements
# * Dataset Source: [Stack Overflow Developer Survey 2025](https://insights.stackoverflow.com/survey)
# * Analysis & Documentation: **L Hareesh**
# * AI Assistance: **ChatGPT**  **Gemini Pro**
#
# ---
#
# ## 📚 References & Resources
#
# * [Google Colab](https://colab.research.google.com/) – Cloud-based Python environment used for running the analysis.
# * [Pandas Documentation](https://pandas.pydata.org/) – Python data analysis library.
# * [NumPy Documentation](https://numpy.org/) – Numerical computing library.
# * [Matplotlib Documentation](https://matplotlib.org/) – Visualization library.
# * [Seaborn Documentation](https://seaborn.pydata.org/) – Statistical data visualization.
# * [YouTube Playlist: Pandas & NumPy Tutorials](https://www.youtube.com/watch?v=GPVsHOlRBBI&list=PLyMom0n-MBrpr1Q3OQC5Od1o1zczHEO0u) – Helpful for learning data manipulation and analysis.
#
# ---

# %%
# Install the necessary library for downloading files from GitHub

# %%
import requests
import os

# Replace with the direct URL to the raw zip file content on GitHub
# You can usually get this by going to the zip file on GitHub, clicking "Raw", and copying the URL
zip_file_url = 'https://github.com/Harish-lvrk/Data-Analysis-project/raw/main/stack-overflow-developer-survey-2020%20(1).zip'
local_zip_path = '/content/downloaded_file.zip'

try:
    # Download the zip file
    response = requests.get(zip_file_url, stream=True)
    response.raise_for_status()  # Raise an exception for bad status codes

    with open(local_zip_path, 'wb') as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)

    print(f"Zip file downloaded to {local_zip_path}")

except requests.exceptions.RequestException as e:
    print(f"Error downloading zip file: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Zip file downloaded to /content/downloaded_file.zip

# %% [markdown]
# ### Explanation of the Code
#
# 1. **Importing Libraries**
#
#    * `requests` is used to make HTTP requests and download files from the internet.
#    * `os` is imported for handling file paths (though not used much here).
#
# 2. **File URL and Destination Path**
#
#    * `zip_file_url` contains the direct download link of the zip file stored in GitHub.
#    * `local_zip_path` specifies the location where the file will be saved locally (here, in the Colab environment under `/content/`).
#
# 3. **Making the Request**
#
#    * `requests.get(zip_file_url, stream=True)` sends a GET request to the URL and enables streaming, which means the file will be downloaded in chunks rather than loading it entirely into memory. This helps when downloading large files.
#
# 4. **Checking the Response**
#
#    * `response.raise_for_status()` checks if the request was successful (status code 200). If not, it raises an error.
#
# 5. **Saving the File**
#
#    * `with open(local_zip_path, 'wb') as f:` opens a new file in **write-binary mode (`wb`)**. Binary mode is necessary since we are writing raw bytes of a zip file, not text.
#    * The `with` statement ensures that the file is properly closed after writing, even if an error occurs.
#
# 6. **Writing in Chunks**
#
#    * The `for chunk in response.iter_content(chunk_size=8192):` loop reads the file data in small pieces (8 KB each) instead of loading the whole file at once.
#    * `f.write(chunk)` writes each chunk to the file until the entire file is downloaded.
#
# 7. **Success Message**
#
#    * If everything goes well, it prints the location of the saved zip file.
#
# 8. **Error Handling**
#
#    * `except requests.exceptions.RequestException as e:` catches errors related to the HTTP request (e.g., wrong URL, network error).
#    * `except Exception as e:` catches any other unexpected errors and prints them.

# %%
import zipfile

# Use the path where the file was downloaded by the previous cell
local_zip_path = '/content/downloaded_file.zip'
extract_path = '/content/extracted_data'

try:
    # Create the extraction directory if it doesn't exist
    os.makedirs(extract_path, exist_ok=True)

    # Open and extract the zip file
    with zipfile.ZipFile(local_zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print(f"Zip file extracted to {extract_path}")

    # List the files in the extracted directory
    print("\nFiles in the zip file:")
    for root, dirs, files in os.walk(extract_path):
        for name in files:
            print(os.path.join(root, name))
        for name in dirs:
            print(os.path.join(root, name))

except FileNotFoundError:
    print(f"Error: Zip file not found at {local_zip_path}. Please ensure the file path is correct and the previous cell ran successfully.")
except Exception as e:
    print(f"Error extracting zip file: {e}")
# Out:
# Zip file extracted to /content/extracted_data
#
# Files in the zip file:
# /content/extracted_data/so_survey_2020.pdf
# /content/extracted_data/README_2020.txt
# /content/extracted_data/survey_results_public.csv
# /content/extracted_data/survey_results_schema.csv

# %% [markdown]
# ### Explanation of Zip Extraction Process
#
# 1. **Importing Libraries**
#
#    * `zipfile` is used to work with ZIP archive files.
#    * `os` is used to manage file paths and directories.
#
# 2. **Setting File Paths**
#
#    * `local_zip_path` stores the location where the ZIP file was downloaded in the previous step.
#    * `extract_path` specifies the folder where the contents of the ZIP file will be extracted.
#
# 3. **Creating Extraction Directory**
#
#    * `os.makedirs(extract_path, exist_ok=True)` ensures the target folder exists. If it doesn’t, it creates it. If it already exists, no error is raised (because of `exist_ok=True`).
#
# 4. **Opening and Extracting the Zip File**
#
#    * `with zipfile.ZipFile(local_zip_path, 'r') as zip_ref:` opens the ZIP file in read mode.
#    * `zip_ref.extractall(extract_path)` extracts all contents of the ZIP file into the given directory.
#
# 5. **Listing Extracted Files**
#
#    * `os.walk(extract_path)` is used to go through all files and subfolders inside the extracted directory.
#    * It prints the paths of both files and folders inside the extracted directory so you can verify the contents.
#
# 6. **Error Handling**
#
#    * `FileNotFoundError`: Triggered if the ZIP file does not exist at the given path.
#    * `Exception as e`: Catches any other unexpected errors during extraction.
#
# ---
#
# ✅ **Summary:** This code safely extracts the downloaded ZIP file into a specified folder, ensures the folder exists before extraction, and lists all files and folders inside it. It also includes error handling for missing files or unexpected issues.
# The `for` loop with `os.walk(extract_path)` goes through the folder where the ZIP file was extracted and lists out everything inside it. Let’s break it step by step:
#
# 1. **`os.walk(extract_path)`**
#
#    * This function goes through the folder (`extract_path`) and gives three things for each directory it visits:
#
#      * `root` → The current folder path.
#      * `dirs` → A list of all sub-folders inside the current folder.
#      * `files` → A list of all files inside the current folder.
#
# 2. **First inner loop (`for name in files:`)**
#
#    * It goes through every file found in that folder.
#    * `os.path.join(root, name)` combines the folder path (`root`) with the file name (`name`) to get the full file path.
#    * `print(...)` then shows the full path of each file.
#
# 3. **Second inner loop (`for name in dirs:`)**
#
#    * It goes through every sub-folder found inside that folder.
#    * Again, `os.path.join(root, name)` creates the full path of the folder.
#    * `print(...)` then shows the full path of each folder.
#
# 👉 In your case, there were **no sub-folders**, only files, so only the file paths were printed.

# %%
import pandas as pd
import numpy as np

# %%
survey_raw_data = pd.read_csv('/content/extracted_data/survey_results_public.csv')

# %%
schema_data = pd.read_csv('/content/extracted_data/survey_results_schema.csv')

# %%
schema_data.shape
# Out:
# (61, 2)

# %% [markdown]
# This code cell uses the `.shape` attribute of the `schema_data` pandas DataFrame.
#
# - `.shape` returns a tuple representing the dimensions of the DataFrame.
# - The output `(61, 2)` indicates that the `schema_data` DataFrame has 61 rows and 2 columns.

# %%
display(survey_raw_data)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %% [markdown]
# The dataset contains over 64,000 responses to 60 questions (although many questions are optional). The responses have been anonymized and there's no personally identifiable information about respondents - just a Randomized respondent ID.

# %%
survey_raw_data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %% [markdown]
# Short codes are used as column names. We can refer to the schema file to see the full text of each question.

# %%
schema_data
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %% [markdown]
# check each question how it looks like
# - here in 'column' column each row indicates the what is the short form of the question in the main data.
# - now change this schema data to convinet form by making the column shortcuts as the index

# %%
schema_data = schema_data.set_index('Column')
display(schema_data)
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
type(schema_data)
# Out:
# pandas.core.frame.DataFrame

# %%
schemq = schema_data.loc['Respondent']
schemq
# Out:
# QuestionText    Randomized respondent ID number (not in order ...
# Name: Respondent, dtype: object

# %% [markdown]
# - as this is simple form like dictinary we can converto inot the simple foramt to access the question

# %%
schema_raw = schema_data.QuestionText
type(schema_raw)
# Out:
# pandas.core.series.Series

# %%
schema_raw['YearsCodePro']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %% [markdown]
# - this is the series data we can access simply like dictionary before the schmea data is in the form of data frame

# %% [markdown]
# ## Data Preparation & Cleaning
#
# While the survey responses contain a wealth of information, we'll limit our analysis to the following areas:
#
# - Demographics of the survey respondents & the global programming community
# - Distribution of programming skills, experience and preferences
# - Employment-related information & preferences
#
# Let's select a subset of columns with the relevant data.

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %% [markdown]
# Let's extract a copy of the data from these columns into a new data frame `survey_df`, which we can continue to modify further without affecting the original data frame.

# %%
survey_df = survey_raw_data[selected_columns].copy()

# %% [markdown]
# - do same for shema to

# %%
schema = schema_raw[selected_columns]

# %%
len(schema)
# Out:
# 20

# %% [markdown]
# - overview of the basic information from the survey data

# %%
survey_df.shape
# Out:
# (64461, 20)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %% [markdown]
# Most columns have the data type object, either because they contain values of different types, or they contain empty values, which are represented `np.NaN`. It appears that every column contains some empty values, since the Non-Null count for every column is lower than the total number of rows (64461). We'll need to deal with empty values and manually adjust the data type for each column on a case-by-case basis.
#
# Only two of the columns were detected as numeric columns (`Age` and `WorkWeekHrs`), even though there are a few other columns which have mostly numeric values. To make our analysis easier, let's convert some other columns into numeric data types, while ignoring any non-numeric value (they will get converted to NaNs)

# %%
age_1st_code_unique = survey_df['Age1stCode'].unique()
age_1st_code_unique
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
yearscodepro_unique = survey_df['YearsCodePro'].unique()
yearscodepro_unique
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %% [markdown]
# - some values need to droped

# %%
yearscode_unique = survey_df['YearsCode'].unique()
yearscode_unique
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode, errors = 'coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode, errors = 'coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro, errors = 'coerce')

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %% [markdown]
# ### Observations from `survey_df.describe()`
#
# Based on the summary statistics from `survey_df.describe()`, we can observe some potential issues in the data:
#
# *   **Age:** The minimum age is listed as 1 and the maximum age as 279. These values are highly improbable for survey respondents and are likely data entry errors or outliers.
# *   **WorkWeekHrs:** The maximum work week hours is reported as 475. Given that there are only 168 hours in a week (7 days * 24 hours), working 475 hours is impossible. This also indicates a data error or an extreme outlier.
#
# These observations suggest that some data cleaning or handling of outliers might be necessary for the 'Age' and 'WorkWeekHrs' columns before performing further analysis.

# %% [markdown]
# There seems to be a problem with the age column, as the minimum value is 1 and max value is 279. This is a common issues with surveys: responses may contain invalid values due to accidental or intentional errors while responding. A simple fix would be ignore the rows where the value in the age column is higher than 100 years or lower than 10 years as invalid survey responses.

# %%
survey_df.drop(survey_df[survey_df.Age < 10].index, inplace=True)
survey_df.drop(survey_df[survey_df.Age > 100].index, inplace=True)

# %% [markdown]
# The same hold true for `WorkWeekHrs`. Let's ignore entries where the value for the column is higher than 140 hours.

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140].index, inplace=True)

# %% [markdown]
# The gender column also allows picking multiple options, but to simplify our analysis, we'll remove values containing options.

# %%
survey_df.Gender.unique()
# Out:
# array(['Man', nan, 'Woman',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man'], dtype=object)

# %%
survey_df['Gender'].value_counts()
# Out:
# Gender
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %% [markdown]
# - replace the with nan other than man and woman

# %%
# Identify rows where Gender is NOT 'Man' or 'Woman'
condition = ~survey_df['Gender'].isin(['Man', 'Woman','Non-binary, genderqueer, or gender non-conforming'])

# Replace only the 'Gender' column values in those rows with np.nan
survey_df.loc[condition, 'Gender'] = np.nan

# %% [markdown]
# we can also use this syntax instead
# survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %% [markdown]
# ### Explanation of Filtering Gender Data
#
# The code `survey_df.where(survey_df.Gender.isin(['Man', 'Woman']), np.nan, inplace=True)` is used to clean the 'Gender' column in your `survey_df` DataFrame by selectively keeping rows based on the 'Gender' value.
#
# Here's a breakdown:
#
# -   **`survey_df.where(...)`**: This is a pandas DataFrame method that replaces values in the DataFrame where the specified condition is `False` with a given value (in this case, `np.nan`).
# -   **`survey_df.Gender.isin(['Man', 'Woman'])`**: This is the condition being checked. It verifies if the value in the 'Gender' column for each row is present within the list `['Man', 'Woman']`.
#     *   If a value is either 'Man' or 'Woman', the condition is `True`.
#     *   If a value is anything else (like 'Non-binary, genderqueer, or gender non-conforming', or combinations like 'Man;Non-binary, genderqueer, or gender non-conforming', or `NaN`), the condition is `False`.
# -   **`np.nan`**: This specifies the value to replace the original data with when the condition is `False`. `np.nan` represents a missing or undefined value in pandas.
# -   **`inplace=True`**: This argument modifies the `survey_df` DataFrame directly, so you don't need to assign the result back to the variable.
#
# In summary, this line of code iterates through the DataFrame and for any row where the 'Gender' is *not* 'Man' or 'Woman', it replaces all values in that entire row with `NaN`. This effectively filters the DataFrame to include only respondents who identified *solely* as 'Man' or 'Woman' for the purpose of further analysis.

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %% [markdown]
# ## Demographics: Country
#
# Let's look at the distribution of survey respondents by country.
# Exploratory Analysis and Visualization
# Before we can ask interesting questions about the survey responses, it would help to understand what the demographics i.e. country, age, gender, education level, employment level etc. of the respondents look like. It's important to explore these variable in order to understand how representative the survey is of the worldwide programming community, as a survey of this scale generally tends to have some selection bias.
# Let's begin by importing matplotlib.pyplot and seaborn.

# %%
country_counts = survey_df.Country.value_counts()
display(country_counts)
# Out:
# Country
# United States       12468
# India                8393
# United Kingdom       3894
# Germany              3879
# Canada               2189
#                     ...
# Chad                    1
# North Korea             1
# Liechtenstein           1
# Gabon                   1
# Marshall Islands        1
# Name: count, Length: 183, dtype: int64

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### Explanation of Visualization Setup
#
# This code cell imports the necessary libraries for data visualization and sets up some basic plotting styles using Matplotlib and Seaborn:
#
# -   **`import seaborn as sns`**: Imports the Seaborn library, which is built on top of Matplotlib and provides a high-level interface for drawing attractive statistical graphics. It's commonly aliased as `sns`.
# -   **`import matplotlib`**: Imports the core Matplotlib library.
# -   **`import matplotlib.pyplot as plt`**: Imports the `pyplot` module from Matplotlib, which provides a MATLAB-like plotting framework. It's commonly aliased as `plt` and is used for creating various types of plots.
# -   **`%matplotlib inline`**: This is a Matplotlib magic command used in interactive environments like Jupyter notebooks or Google Colab. It ensures that the plots generated by Matplotlib are displayed directly within the notebook output, rather than in a separate window.
# -   **`sns.set_style('darkgrid')`**: Sets the visual style of the plots to 'darkgrid' using Seaborn. This adds a dark grid background to the plots, which can improve readability.
# -   **`matplotlib.rcParams[...]`**: These lines modify the default parameters for Matplotlib plots:
#     *   `'font.size': 14`: Sets the default font size for text elements in plots to 14.
#     *   `'figure.figsize': (9, 5)`: Sets the default size for figures (plots) to 9 inches wide by 5 inches tall.
#     *   `'figure.facecolor': '#00000000'`: Sets the default background color of figures to fully transparent.
#
# These settings help create visually appealing and consistently styled plots throughout the notebook.

# %%
# Calculate the percentage of respondents per country
country_percentages = country_counts / survey_df.Country.count() * 100
display(country_percentages)
# Out:
# Country
# United States       19.506548
# India               13.131092
# United Kingdom       6.092276
# Germany              6.068808
# Canada               3.424754
#                       ...
# Chad                 0.001565
# North Korea          0.001565
# Liechtenstein        0.001565
# Gabon                0.001565
# Marshall Islands     0.001565
# Name: count, Length: 183, dtype: float64

# %%
schema.Country
# Out:
# 'Where do you live?'

# %%
survey_df.Country.unique()
# Out:
# array(['Germany', 'United Kingdom', 'Russian Federation', 'Albania',
#        'United States', 'India', 'Tunisia', 'Spain', 'Netherlands',
#        'France', 'Belgium', 'Portugal', 'Canada', 'China', 'Ukraine',
#        'Italy', 'Brazil', 'Austria', 'Mexico', 'Sweden', 'Poland',
#        'Indonesia', 'Greece', 'Israel', 'Czech Republic',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Serbia', 'Switzerland',
#        'Hungary', 'Nepal', 'Slovenia', 'Uruguay', 'Denmark', 'Pakistan',
#        'Taiwan', 'Romania', 'Finland', 'Costa Rica', 'Nigeria', 'Chile',
#        'Turkey', 'Panama', 'Ireland', 'Estonia', 'Philippines',
#        'Australia', 'Nomadic', 'Peru', 'Cyprus', 'Sri Lanka', 'Kenya',
#        'Norway', 'Kyrgyzstan', 'Iran', 'Croatia', 'Egypt', 'Argentina',
#        'Ghana', 'Latvia', 'Morocco', 'Bangladesh', 'Ecuador', 'Haiti',
#        'Venezuela, Bolivarian Republic of...', 'Colombia', 'Lithuania',
#        'El Salvador', 'Honduras', 'Ethiopia', 'Lebanon', 'Uganda',
# ...

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
survey_df.Country.value_counts()
# Out:
# Country
# United States       12468
# India                8393
# United Kingdom       3894
# Germany              3879
# Canada               2189
#                     ...
# Chad                    1
# North Korea             1
# Liechtenstein           1
# Gabon                   1
# Marshall Islands        1
# Name: count, Length: 183, dtype: int64

# %%
top_15_countries = survey_df.Country.value_counts().head(15)
top_15_countries
# Out:
# Country
# United States         12468
# India                  8393
# United Kingdom         3894
# Germany                3879
# Canada                 2189
# France                 1893
# Brazil                 1811
# Netherlands            1340
# Poland                 1263
# Australia              1208
# Spain                  1160
# Italy                  1115
# Russian Federation     1091
# Sweden                  884
# Pakistan                808
# Name: count, dtype: int64

# %%
# Select the top 15 countries (counts)
top_15_countries = survey_df.Country.value_counts().head(15)

# Increase figure size
plt.figure(figsize=(12, 8))

# Create the bar plot using counts
sns.barplot(x=top_15_countries.index, y=top_15_countries)

# Set plot title and labels
plt.title('Top 15 Countries by Number of Respondents')
plt.xlabel('Country')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels by 45 degrees and align to the right

# Display the plot
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# It appears the that a disproportionately high number of respondents are from USA & India - which one might expect since these countries have the highest populations (apart from China), and since the Survey is in English, which is the common language used by professionals in US, India & UK. We can already see that the survey may not be representative of the entire programming community - especially from non-English speaking countries.

# %% [markdown]
# ### Explanation of the Top 15 Countries Bar Plot
#
# This code block generates a bar plot showing the top 15 countries with the most survey respondents using the Seaborn and Matplotlib libraries.
#
# Here's a breakdown:
#
# 1.  **`top_15_countries = survey_df.Country.value_counts().head(15)`**:
#     *   `survey_df.Country.value_counts()`: This calculates the number of occurrences for each unique country in the 'Country' column and returns a pandas Series where the index is the country name and the values are the counts, sorted in descending order.
#     *   `.head(15)`: This selects the top 15 entries from the sorted Series, giving you the 15 countries with the highest number of respondents.
#     *   The result is stored in the variable `top_15_countries`.
#
# 2.  **`plt.figure(figsize=(12, 8))`**:
#     *   This creates a new figure for the plot and sets its size to 12 inches wide and 8 inches tall. This is done using Matplotlib's `pyplot` module (aliased as `plt`).
#
# 3.  **`sns.barplot(x=top_15_countries.index, y=top_15_countries)`**:
#     *   This is the core line that creates the bar plot using Seaborn.
#     *   `sns.barplot()`: The function to create a bar plot.
#     *   `x=top_15_countries.index`: Sets the x-axis labels to the index of the `top_15_countries` Series, which are the names of the top 15 countries.
#     *   `y=top_15_countries`: Sets the y-axis values to the values of the `top_15_countries` Series, which are the counts of respondents for each country.
#
# 4.  **`plt.title('Top 15 Countries by Number of Respondents')`**: Sets the title of the plot.
# 5.  **`plt.xlabel('Country')`**: Sets the label for the x-axis.
# 6.  **`plt.ylabel('Number of Respondents')`**: Sets the label for the y-axis.
# 7.  **`plt.xticks(rotation=45, ha='right')`**:
#     *   `plt.xticks()`: This function is used to customize the x-axis ticks (the labels under each bar).
#     *   `rotation=45`: Rotates the x-axis labels (country names) by 45 degrees to prevent them from overlapping, especially when there are many labels.
#     *   `ha='right'`: Aligns the rotated labels to the right side of the tick marks.
#
# 8.  **`plt.tight_layout()`**: Automatically adjusts the plot parameters for a tight layout, preventing labels or titles from overlapping.
# 9.  **`plt.show()`**: Displays the generated plot.
#
# In summary, this code prepares the data for the top 15 countries by respondent count and then uses Seaborn and Matplotlib to create and display a visually clear bar plot of this data with rotated labels for better readability.

# %% [markdown]
# # Age

# %% [markdown]
# # Age

# %%
plt.figure(figsize=(10, 6))
sns.histplot(survey_df['Age'].dropna(), bins=30, kde=True)
plt.title('Distribution of Respondent Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Explanation of Age Distribution Histogram
#
# This code generates a histogram to visualize the distribution of respondent ages in the `survey_df` DataFrame using Seaborn and Matplotlib.
#
# -   **`plt.figure(figsize=(10, 6))`**: Creates a new figure for the plot with a size of 10 inches wide by 6 inches tall.
# -   **`sns.histplot(survey_df['Age'].dropna(), bins=30, kde=True)`**: This is the core line that creates the histogram.
#     *   `survey_df['Age'].dropna()`: Selects the 'Age' column from the `survey_df` DataFrame and removes any missing values (`NaN`) before plotting.
#     *   `bins=30`: Specifies the number of bins (intervals) for the histogram. 30 bins provide a reasonable level of detail for the age distribution.
#     *   `kde=True`: Adds a Kernel Density Estimate (KDE) line to the plot, which provides a smoothed representation of the distribution.
# -   **`plt.title('Distribution of Respondent Age')`**: Sets the title of the plot.
# -   **`plt.xlabel('Age')`**: Sets the label for the x-axis.
# -   **`plt.ylabel('Count')`**: Sets the label for the y-axis.
# -   **`plt.show()`**: Displays the generated plot.
#
# The histogram shows how frequently different age ranges appear in the survey responses, giving you a visual summary of the age demographics of the respondents. The KDE line helps to see the overall shape of the distribution.

# %% [markdown]
# # Gender

# %%
schema.Gender
# Out:
# 'Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
gender_counts = survey_df.Gender.value_counts(dropna=False)
display(gender_counts)
# Out:
# Gender
# Man                                                  45895
# NaN                                                  14191
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
# Calculate percentages for the pie chart
gender_percentages = gender_counts / gender_counts.sum() * 100

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(gender_percentages, labels=gender_percentages.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))

# Add a title
plt.title('Distribution of Respondent Gender')

# Ensure the pie chart is circular
plt.axis('equal')

plt.show()

# %% [markdown]
# Only about 8% of survey respondents who have answered the question identify as women or non-binary. This number is lower than the overall percentage of women & non-binary genders in the programming community - which is estimated to be around 12%-
# Exercise: It would be interesting to compare the survey responses & preferences across genders, and you are encouraged to repeat this analysis with these breakdowns. How do the relative education levels differ across genders? How to salaries differ? You may find this analysis on the Gender Divide in Data Science useful.

# %% [markdown]
# ### Explanation of Gender Distribution Pie Chart
#
# This code generates a pie chart to visualize the distribution of respondent gender using the `gender_counts` data.
#
# - **`gender_percentages = gender_counts / gender_counts.sum() * 100`**: Calculates the percentage for each gender category by dividing the count of each category by the total number of responses and multiplying by 100.
# - **`plt.figure(figsize=(8, 8))`**: Creates a square figure for the pie chart.
# - **`plt.pie(...)`**: Generates the pie chart:
#     - `gender_percentages`: Provides the sizes of the wedges.
#     - `labels=gender_percentages.index`: Uses the gender categories (Man, Woman, NaN, Non-binary...) as labels for the wedges.
#     - `autopct='%1.1f%%'`: Displays the percentage on each wedge with one decimal place.
#     - `startangle=140`: Rotates the starting point of the first wedge.
#     - `colors=sns.color_palette('pastel')`: Uses a pleasant color palette from Seaborn.
# - **`plt.title('Distribution of Respondent Gender')`**: Sets the title of the pie chart.
# - **`plt.axis('equal')`**: Ensures the pie chart is drawn as a circle.
# - **`plt.show()`**: Displays the generated plot.
#
# **Intuitive Explanation:**
#
# The code takes the counts of each gender category, calculates their proportion of the total, and then draws a circle divided into slices. Each slice represents a gender category, and the size of the slice corresponds to its percentage of the total responses. The percentages are shown on each slice for easy understanding.
#
# ### Overview of the Output
#
# The pie chart visually represents the proportion of respondents in each gender category. You can clearly see the dominant category (Man) and the relative sizes of the other categories (Woman, Non-binary, and NaN/Unspecified). This helps in quickly understanding the gender distribution within the survey data.

# %%
# Age distribution by Gender
plt.figure(figsize=(10, 6))
sns.histplot(data=survey_df, x='Age', hue='Gender', multiple='stack', bins=30, kde=True)
plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Explanation of Age Distribution by Gender Plot
#
# This code generates a stacked histogram to visualize the age distribution of respondents, broken down by gender, using Seaborn and Matplotlib.
#
# - **`plt.figure(figsize=(10, 6))`**: Creates a figure for the plot with a specified size.
# - **`sns.histplot(data=survey_df, x='Age', hue='Gender', multiple='stack', bins=30, kde=True)`**: This is the core plotting function.
#     - `data=survey_df`: Specifies the DataFrame to use.
#     - `x='Age'`: Sets the 'Age' column as the data for the x-axis.
#     - `hue='Gender'`: This is key for breaking down the histogram by gender. Seaborn will create separate bars (or sections of bars) for each unique value in the 'Gender' column.
#     - `multiple='stack'`: Stacks the bars for each gender on top of each other within each age bin. This allows you to see the total count for each age range and how that count is composed of different genders.
#     - `bins=30`: Specifies the number of bins for the histogram.
#     - `kde=True`: Adds a Kernel Density Estimate (KDE) line for each gender category, providing a smoothed estimate of their age distributions.
# - **`plt.title('Age Distribution by Gender')`**: Sets the title of the plot.
# - **`plt.xlabel('Age')`**: Sets the label for the x-axis.
# - **`plt.ylabel('Count')`**: Sets the label for the y-axis.
# - **`plt.show()`**: Displays the generated plot.
#
# **Intuitive Explanation:**
#
# Imagine you're sorting the survey responses first by age group and then by gender within each age group. This plot visually shows you how many people of each gender fall into different age brackets. The stacked bars let you compare the counts of 'Man', 'Woman', and 'Non-binary, genderqueer, or gender non-conforming' within each age range, and the lines show the general shape of the age distribution for each group.
#
# ### Overview of the Output
#
# The output is a stacked histogram. Each bar represents an age range (defined by the bins). The height of the bar shows the total number of respondents in that age range. Within each bar, different colors represent the different gender categories ('Man', 'Woman', 'Non-binary, genderqueer, or gender non-conforming'). The lines provide a smoothed view of the age distribution for each gender.
#
# From this plot, you can observe the general age range of respondents and how the distribution of genders varies across different ages. For example, you can see which age groups have a higher or lower proportion of 'Woman' or 'Non-binary, genderqueer, or gender non-conforming' respondents compared to 'Man' respondents.

# %%
# Education Level

# %%
schema.EdLevel
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed?'

# %%
survey_df['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26482
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       13071
# Some college/university study without earning a degree                                 7220
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4756
# Associate degree (A.A., A.S., etc.)                                                    1840
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1688
# Primary/elementary school                                                               937
# Professional degree (JD, MD, etc.)                                                      799
# I never completed any formal education                                                  487
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 10))
sns.countplot(data=survey_df, y='EdLevel', hue='EdLevel', palette="Set2", legend=False)
plt.xticks(rotation=75)
plt.title(schema['EdLevel'])
plt.ylabel(None)
plt.show()

# %% [markdown]
# It appears that well over half of the respondents hold a bachelor's or master's degree, so most programmers definitely seem to have some college education, although it's not clear from this graph alone if they hold a degree in computer science.
# Exercises: The graph currently shows the number of respondents for each option, can you modify it to show the percentage instead? Further, can you break down the graph to compare the percentages for each degree for men vs. women.

# %% [markdown]
# ### Explanation of Education Level Count Plot
#
# This code generates a horizontal bar plot to visualize the distribution of education levels among the survey respondents using Seaborn and Matplotlib.
#
# - **`plt.figure(figsize=(12, 10))`**: Creates a figure for the plot with a specified size (12 inches wide, 10 inches tall).
# - **`sns.countplot(data=survey_df, y='EdLevel', order=survey_df['EdLevel'].value_counts().index)`**: This is the core plotting function.
#     - `data=survey_df`: Specifies the DataFrame to use.
#     - `y='EdLevel'`: Sets the 'EdLevel' column as the data for the y-axis. This creates horizontal bars.
#     - `order=survey_df['EdLevel'].value_counts().index`: Orders the bars based on the frequency of each education level, from most to least frequent.
# - **`plt.title('Distribution of Education Level')`**: Sets the title of the plot.
# - **`plt.xlabel('Count')`**: Sets the label for the x-axis (since the bars are horizontal).
# - **`plt.ylabel('Education Level')`**: Sets the label for the y-axis (the different education levels).
# - **`plt.xticks(rotation=75)`**: Rotates the x-axis labels (the counts) by 75 degrees to prevent overlap.
# - **`plt.tight_layout()`**: Adjusts the plot to prevent labels from overlapping.
# - **`plt.show()`**: Displays the generated plot.
#
# **Intuitive Explanation:**
#
# This plot acts like a tally counter for education levels. It looks at every respondent's stated education and creates a bar for each unique level. The longer the bar, the more respondents have that particular education level. The bars are arranged from most common to least common, and the numbers along the bottom (the counts) are tilted so they don't bump into each other.
#
# ### Overview of the Output
#
# The output is a horizontal bar chart showing the number of respondents for each category in the 'EdLevel' column. You can quickly see which education levels are most common among the survey participants (e.g., Bachelor's degree, Master's degree) and the relative frequency of less common education levels. The bars are ordered by count, making it easy to identify the most prevalent educational backgrounds. Each bar will have a different color based on Seaborn's default color cycle.

# %%
schema.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
survey_df['UndergradMajor'].value_counts()
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   31499
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4745
# Information systems, information technology, or system administration              4054
# A natural science (such as biology, chemistry, physics, etc.)                      2200
# Mathematics or statistics                                                          1848
# Web development or web design                                                      1788
# A business discipline (such as accounting, finance, marketing, etc.)               1370
# A humanities discipline (such as literature, history, philosophy, etc.)            1007
# A social science (such as anthropology, psychology, political science, etc.)        932
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      725
# ...

# %%
undergrad_pct=  survey_df['UndergradMajor'].value_counts()*100/survey_df['UndergradMajor'].count()
undergrad_pct
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   61.919365
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       9.327515
# Information systems, information technology, or system administration              7.969177
# A natural science (such as biology, chemistry, physics, etc.)                      4.324664
# Mathematics or statistics                                                          3.632718
# Web development or web design                                                      3.514773
# A business discipline (such as accounting, finance, marketing, etc.)               2.693086
# A humanities discipline (such as literature, history, philosophy, etc.)            1.979517
# A social science (such as anthropology, psychology, political science, etc.)       1.832085
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     1.425173
# ...

# %%
# Calculate percentages of each undergrad major by gender
undergrad_gender_counts = survey_df.groupby('Gender')['UndergradMajor'].value_counts(normalize=True).mul(100).rename('percentage').reset_index()
undergrad_gender_counts
# Out:
#                                                Gender  \
# 0                                                 Man
# 1                                                 Man
# 2                                                 Man
# 3                                                 Man
# 4                                                 Man
# 5                                                 Man
# 6                                                 Man
# 7                                                 Man
# 8                                                 Man
# 9                                                 Man
# 10                                                Man
# 11                                                Man
# 12  Non-binary, genderqueer, or gender non-conforming
# 13  Non-binary, genderqueer, or gender non-conforming
# 14  Non-binary, genderqueer, or gender non-conforming
# 15  Non-binary, genderqueer, or gender non-conforming
# ...

# %%
plt.figure(figsize=(12, 8))



# Plot the data
sns.barplot(data=undergrad_gender_counts, x='percentage', y='UndergradMajor', hue='Gender')

plt.title(schema.UndergradMajor)
plt.xlabel('Percentage')
plt.ylabel(None)
plt.show()

# %% [markdown]
# ### Explanation of Undergraduate Major Distribution by Gender Plot
#
# This code generates a horizontal bar plot to visualize the distribution of undergraduate majors among survey respondents, broken down by gender, using Seaborn and Matplotlib.
#
# - **`plt.figure(figsize=(12, 8))`**: Creates a figure for the plot with a specified size (12 inches wide, 8 inches tall) for better readability.
# - **`undergrad_gender_counts = survey_df.groupby('Gender')['UndergradMajor'].value_counts(normalize=True).mul(100).rename('percentage').reset_index()`**: This is a crucial step for preparing the data for the plot.
#     - `survey_df.groupby('Gender')`: Groups the DataFrame by the 'Gender' column.
#     - `['UndergradMajor'].value_counts(normalize=True)`: Within each gender group, it calculates the proportion of each unique value in the 'UndergradMajor' column. `normalize=True` makes these proportions relative to the total within each gender group.
#     - `.mul(100)`: Multiplies the proportions by 100 to get percentages.
#     - `.rename('percentage')`: Renames the resulting Series to 'percentage'.
#     - `.reset_index()`: Converts the Series back into a DataFrame with 'Gender', 'UndergradMajor', and 'percentage' as columns. This structure is suitable for plotting with Seaborn.
# - **`sns.barplot(data=undergrad_gender_counts, x='percentage', y='UndergradMajor', hue='Gender')`**: This is the core plotting function.
#     - `data=undergrad_gender_counts`: Specifies the newly created DataFrame containing the calculated percentages by gender and major.
#     - `x='percentage'`: Sets the 'percentage' column as the data for the x-axis.
#     - `y='UndergradMajor'`: Sets the 'UndergradMajor' column as the data for the y-axis, creating horizontal bars.
#     - `hue='Gender'`: Creates separate bars (or groups of bars) for each gender within each undergraduate major category, allowing for a direct comparison of the percentage distribution across genders.
# - **`plt.title(schema.UndergradMajor)`**: Sets the title of the plot using the full question text from the schema for the 'UndergradMajor' column.
# - **`plt.xlabel('Percentage')`**: Sets the label for the x-axis.
# - **`plt.ylabel(None)`**: Removes the default label for the y-axis since the labels for the bars themselves (the undergraduate majors) are sufficient.
# - **`plt.show()`**: Displays the generated plot.
#
# ### Overview of the Output
#
# The output is a horizontal bar chart that shows the percentage of respondents within each gender category who majored in different fields during their undergraduate studies.
#
# *   Each row of bars represents an undergraduate major.
# *   Within each row, there are separate colored bars for each gender ('Man', 'Woman', and 'Non-binary, genderqueer, or gender non-conforming').
# *   The length of each colored bar indicates the percentage of respondents of that specific gender who reported having that particular undergraduate major.
#
# From this plot, you can observe:
#
# *   Which undergraduate majors are most common overall.
# *   How the percentage of each major differs between genders. For example, you can see if a higher percentage of men or women majored in computer science, engineering, or other fields.
# *   The relative proportion of each gender within different academic backgrounds.

# %%
schema.NEWEdImpt
# Out:
# 'How important is a formal education, such as a university degree in computer science, to your career?'

# %%
survey_df['NEWEdImpt'].value_counts()
# Out:
# NEWEdImpt
# Fairly important                      12633
# Very important                        11836
# Somewhat important                    11357
# Not at all important/not necessary     7758
# Critically important                   4739
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=survey_df, y='NEWEdImpt', order=survey_df['NEWEdImpt'].value_counts().index)
plt.title(schema['NEWEdImpt'])
plt.xlabel('Count')
plt.ylabel(None)
plt.show()

# %% [markdown]
# ### Analysis: Importance of Formal Education by Undergraduate Major
#
# Let's compare the distribution of responses to the question "How important is a formal education...?" for respondents who majored in "Computer science, computer engineering, or software engineering" versus those who majored in other fields.

# %%
# Filter the DataFrame to separate Computer Science majors and others
cs_majors_df = survey_df[survey_df['UndergradMajor'] == 'Computer science, computer engineering, or software engineering']
other_majors_df = survey_df[survey_df['UndergradMajor'] != 'Computer science, computer engineering, or software engineering']

# Get the value counts for NEWEdImpt for each group
cs_ed_importance = cs_majors_df['NEWEdImpt'].value_counts(normalize=True).mul(100)
display(cs_ed_importance)
other_ed_importance = other_majors_df['NEWEdImpt'].value_counts(normalize=True).mul(100)
display(other_ed_importance)
# Combine the results into a single DataFrame for plotting
ed_importance_comparison = pd.DataFrame({
    'Computer Science Majors': cs_ed_importance,
    'Other Majors': other_ed_importance
}).reset_index()
display(ed_importance_comparison)
ed_importance_comparison = ed_importance_comparison.melt(id_vars='NEWEdImpt', var_name='Major Type', value_name='Percentage')
ed_importance_comparison = ed_importance_comparison.rename(columns={'NEWEdImpt': 'Education Importance'})


display(ed_importance_comparison)
# Out:
# NEWEdImpt
# Very important                        29.054398
# Fairly important                      29.010821
# Somewhat important                    21.032755
# Critically important                  11.257172
# Not at all important/not necessary     9.644854
# Name: proportion, dtype: float64
# NEWEdImpt
# Somewhat important                    26.774116
# Not at all important/not necessary    24.546548
# Fairly important                      22.343036
# Very important                        18.450806
# Critically important                   7.885494
# Name: proportion, dtype: float64
#                             NEWEdImpt  Computer Science Majors  Other Majors
# 0                Critically important                11.257172      7.885494
# 1                    Fairly important                29.010821     22.343036
# 2  Not at all important/not necessary                 9.644854     24.546548
# 3                  Somewhat important                21.032755     26.774116
# ...

# %%
# Plot the comparison
plt.figure(figsize=(12, 7))
sns.barplot(data=ed_importance_comparison, x='Percentage', y='Education Importance', hue='Major Type')
plt.title('Importance of Formal Education: CS Majors vs. Other Majors')
plt.xlabel('Percentage of Respondents')
plt.ylabel('Importance Rating')
plt.show()

# %% [markdown]
# ### Explanation of Importance of Formal Education by Undergraduate Major Analysis and Plot
#
# This analysis and the resulting bar plot compare how important formal education is perceived to be by survey respondents, specifically differentiating between those who majored in Computer Science (or related fields) and those with other undergraduate majors.
#
# **Code Breakdown:**
#
# 1.  **Filtering Data:**
#     *   `cs_majors_df = survey_df[survey_df['UndergradMajor'] == 'Computer science, computer engineering, or software engineering']`: This line creates a new DataFrame `cs_majors_df` containing only the rows where the 'UndergradMajor' is 'Computer science, computer engineering, or software engineering'.
#     *   `other_majors_df = survey_df[survey_df['UndergradMajor'] != 'Computer science, computer engineering, or software engineering']`: This line creates another DataFrame `other_majors_df` with rows where the 'UndergradMajor' is anything other than Computer Science.
#
# 2.  **Calculating Percentages:**
#     *   `cs_ed_importance = cs_majors_df['NEWEdImpt'].value_counts(normalize=True).mul(100)`: This calculates the percentage distribution of responses to the 'NEWEdImpt' question within the `cs_majors_df` (Computer Science majors). `value_counts(normalize=True)` gives the proportions, and `.mul(100)` converts them to percentages.
#     *   `other_ed_importance = other_majors_df['NEWEdImpt'].value_counts(normalize=True).mul(100)`: This does the same calculation for the `other_majors_df` (other majors).
#
# 3.  **Preparing Data for Plotting:**
#     *   `ed_importance_comparison = pd.DataFrame({...}).reset_index()`: This creates a new DataFrame `ed_importance_comparison` with two columns: 'Computer Science Majors' and 'Other Majors', containing the percentage distributions calculated in the previous step. `reset_index()` converts the index (the importance ratings like "Very important") into a regular column.
#     *   `ed_importance_comparison = ed_importance_comparison.melt(...)`: This uses the `melt()` function to transform the DataFrame from a wide format (one column per major type) to a long format. This is necessary for Seaborn's `barplot` when using the `hue` parameter. It creates columns for 'Education Importance' (the original index), 'Major Type' (indicating 'Computer Science Majors' or 'Other Majors'), and 'Percentage' (the corresponding percentage value).
#     *   `ed_importance_comparison = ed_importance_comparison.rename(...)`: This renames the column created by `melt()` to 'Education Importance' for clarity.
#
# 4.  **Generating the Plot:**
#     *   `plt.figure(figsize=(12, 7))`: Sets the size of the plot.
#     *   `sns.barplot(data=ed_importance_comparison, x='Percentage', y='Education Importance', hue='Major Type')`: This creates the horizontal bar plot.
#         *   `data=ed_importance_comparison`: Specifies the prepared DataFrame.
#         *   `x='Percentage'`: Sets the x-axis to the percentage values.
#         *   `y='Education Importance'`: Sets the y-axis to the importance ratings, creating horizontal bars.
#         *   `hue='Major Type'`: Creates separate bars for 'Computer Science Majors' and 'Other Majors' for each importance rating, allowing for direct comparison.
#     *   `plt.title(...)`, `plt.xlabel(...)`, `plt.ylabel(...)`: Sets the title and axis labels.
#     *   `plt.show()`: Displays the plot.
#
# **Overview of the Output:**
#
# The output is a grouped horizontal bar chart.
#
# *   Each group of bars corresponds to an importance rating (e.g., "Very important").
# *   Within each group, there are two bars: one for "Computer Science Majors" (blue) and one for "Other Majors" (orange).
# *   The length of each bar visually represents the percentage of respondents within that major type who selected that specific importance rating for formal education.
#
# This visualization allows us to easily compare the distribution of opinions on the importance of formal education between developers with a Computer Science background and those with other educational backgrounds. We can see which importance levels are more prevalent in each group and the relative differences in their perspectives.

# %% [markdown]
# # Employement
# Freelancing or contract work is a common choice among programmer, so it would be interesting to compare the breakdown between full time, part time & freelance work. Let's visualize the data from Employment column.

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
(survey_df.Employment.value_counts(normalize = True, ascending= True)*100).plot(kind='barh')
plt.title(schema.Employment)
plt.xlabel('Percentage');

# %%
# Calculate employment percentages
employment_percentages = survey_df.Employment.value_counts(normalize=True) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(employment_percentages, labels=employment_percentages.index, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title(schema.Employment)

# Ensure the pie chart is circular
plt.axis('equal')

plt.show()

# %% [markdown]
# - that why i dont used the pie chart

# %%
# Calculate employment counts
employment_counts = survey_df['Employment'].value_counts()

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(y=employment_counts.index, x=employment_counts)

# Set plot title and labels
plt.title(schema.Employment)
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability

# Display the plot
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %% [markdown]
# The DevType field contains information about the roles held by respondents. Since the question allows multiple answers, the column contains lists of values separated by which makes it a bit harder to analyze directly.

# %%
survey_df.DevType.value_counts()
# Out:
# DevType
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                                                                        4416
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3073
# ...

# %%
# Split the strings in the 'DevType' column by semicolon and stack them
dev_types = survey_df['DevType'].str.split(';', expand=True).stack()
display(dev_types)
# Get the value counts of each developer type
dev_type_counts = dev_types.value_counts()

# Display the counts
display(dev_type_counts)
# Out:
# 0      0    Developer, desktop or enterprise applications
#        1                            Developer, full-stack
# 1      0                            Developer, full-stack
#        1                                Developer, mobile
# 5      0                                         Designer
#                                 ...
# 64453  0                         Data or business analyst
#        1                                Developer, mobile
#        2                              Senior executive/VP
#        3                             System administrator
# 64456  0                              Senior executive/VP
# Length: 156534, dtype: object
# Developer, back-end                              27137
# Developer, full-stack                            27046
# Developer, front-end                             18230
# Developer, desktop or enterprise applications    11742
# Developer, mobile                                 9447
# ...

# %%
survey_df.DevType.value_counts()
# Out:
# DevType
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                                                                        4416
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3073
# ...

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    # Iterate over the column
    for idx, value  in col_series[col_series.notnull()].items():
        # Break each value into list of options
        for option in value.split(';'):
            # Add the option as a column to result
            if not option in result_df.columns:
                options.append(option)
                result_df[ option] = False
            # Mark the value in the option column as True
            result_df.at[idx, option] = True
    return result_df[options]

# %%
display(survey_df.DevType)
display(survey_df.DevType.to_frame())
type(survey_df.DevType)
type(survey_df.DevType.to_frame())
# Out:
# 0        Developer, desktop or enterprise applications;...
# 1                  Developer, full-stack;Developer, mobile
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 64456                                  Senior executive/VP
# 64457                                                  NaN
# 64458                                                  NaN
# 64459                                                  NaN
# 64460                                                  NaN
# Name: DevType, Length: 64306, dtype: object
#                                                  DevType
# 0      Developer, desktop or enterprise applications;...
# 1                Developer, full-stack;Developer, mobile
# 2                                                    NaN
# 3                                                    NaN
# ...

# %%
# Split the strings in the 'DevType' column by semicolon and stack them
dev_types = split_multicolumn(survey_df['DevType'])

# %%
dev_types
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
# Get the value counts of each developer type
dev_type_counts = dev_types.sum().sort_values(ascending=False)

# Display the counts
display(dev_type_counts)
# Out:
# Developer, back-end                              27137
# Developer, full-stack                            27046
# Developer, front-end                             18230
# Developer, desktop or enterprise applications    11742
# Developer, mobile                                 9447
# DevOps specialist                                 5949
# Database administrator                            5697
# Designer                                          5307
# System administrator                              5221
# Developer, embedded applications or devices       4729
# Data or business analyst                          4008
# Data scientist or machine learning specialist     3974
# Developer, QA or test                             3926
# Engineer, data                                    3729
# Academic researcher                               3534
# Educator                                          2916
# Developer, game or graphics                       2778
# ...
